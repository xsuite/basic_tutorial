# %%
pip install xsuite
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xsuite in /eos/home-i02/s/szlopaci/.local/lib/python3.9/site-packages (0.5.0)
# Requirement already satisfied: xfields in /eos/home-i02/s/szlopaci/.local/lib/python3.9/site-packages (from xsuite) (0.11.2)
# Requirement already satisfied: xobjects in /eos/home-i02/s/szlopaci/.local/lib/python3.9/site-packages (from xsuite) (0.2.3)
# Requirement already satisfied: xpart in /eos/home-i02/s/szlopaci/.local/lib/python3.9/site-packages (from xsuite) (0.14.3)
# Requirement already satisfied: xtrack in /eos/home-i02/s/szlopaci/.local/lib/python3.9/site-packages (from xsuite) (0.32.1)
# Requirement already satisfied: numpy>=1.0 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from xsuite) (1.22.3)
# Requirement already satisfied: xdeps in /eos/home-i02/s/szlopaci/.local/lib/python3.9/site-packages (from xsuite) (0.0.14)
# Requirement already satisfied: lark in /eos/home-i02/s/szlopaci/.local/lib/python3.9/site-packages (from xdeps->xsuite) (1.1.5)
# Requirement already satisfied: scipy in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from xfields->xsuite) (1.8.0)
# Requirement already satisfied: pandas in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from xfields->xsuite) (1.2.2)
# Requirement already satisfied: cffi in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from xobjects->xsuite) (1.14.6)
# Requirement already satisfied: pycparser in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from cffi->xobjects->xsuite) (2.20)
# Requirement already satisfied: python-dateutil>=2.7.3 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from pandas->xfields->xsuite) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from pandas->xfields->xsuite) (2021.1)
# Requirement already satisfied: six>=1.5 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->xfields->xsuite) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib widget
import ipympl

import numpy as np
import matplotlib.pyplot as plt

import xpart as xp
import xtrack as xt

fname_model = './generate_models/sps_acceleration.json'

nemitt_x = 2.5e-6
nemitt_y = 2.5e-6

line = xt.Line.from_json(fname_model)
line.build_tracker()
# Out:
# Done loading line from dict.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.

# %% [markdown]
# ## Exploring the SPS
#
# The beamline of the SPS is accessible through `line`. Some examples on how we can access the elements of the line.
#
# ### Enumerate elements and their names

# %%
line.element_names  # Element names
# Out:
# ('sps$start',
#  'mystart',
#  'drift_0',
#  'bmo.51997_aper',
#  'bmo.51997',
#  'drift_1',
#  'tacw.51998',
#  'drift_2',
#  'bpmb.51999_aper',
#  'bpmb.51999',
#  'drift_3',
#  'loen.52002_aper',
#  'loen.52002',
#  'drift_4',
#  'lsf.52005_aper',
#  'lsf.52005',
#  'drift_5',
#  'mdh.52007_aper',
#  'mdh.52007',
#  'drift_6',
#  'bph.52008_aper',
#  'bph.52008',
#  'drift_7',
#  'qf.52010_aper',
#  'qf.52010',
#  'drift_8',
#  'mba.52030_den',
#  'drift_9',
#  'mba.52030_aper',
#  'mba.52030',
#  'drift_10',
#  'mba.52030_dex',
#  'drift_11',
#  'mba.52050_den',
#  'drift_12',
#  'mba.52050_aper',
#  'mba.52050',
#  'drift_13',
#  'mba.52050_dex',
#  'drift_14',
#  'mbb.52070_den',
#  'drift_15',
#  'mbb.52070_aper',
#  'mbb.52070',
#  'drift_16',
#  'mbb.52070_dex',
#  'drift_17',
#  'mbb.52090_den',
#  'drift_18',
#  'mbb.52090_aper',
#  'mbb.52090',
#  'drift_19',
#  'mbb.52090_dex',
#  'drift_20',
#  'brcz.52102_aper',
#  'brcz.52102',
#  'drift_21',
#  'mdv.52107_aper',
#  'mdv.52107',
#  'drift_22',
#  'bpv.52108_aper',
#  'bpv.52108',
#  'drift_23',
#  'qd.52110_aper',
#  'qd.52110',
#  'drift_24',
#  'mbb.52130_den',
#  'drift_25',
#  'mbb.52130_aper',
#  'mbb.52130',
#  'drift_26',
#  'mbb.52130_dex',
#  'drift_27',
#  'mbb.52150_den',
#  'drift_28',
#  'mbb.52150_aper',
#  'mbb.52150',
#  'drift_29',
#  'mbb.52150_dex',
#  'drift_30',
#  'brsc.52191_aper',
#  'brsc.52191',
#  'drift_31',
#  'tal.52196',
#  'drift_32',
#  'mdh.52207_aper',
#  'mdh.52207',
#  'drift_33',
#  'bph.52208_aper',
#  'bph.52208',
#  'drift_34',
#  'qf.52210_aper',
#  'qf.52210',
#  'drift_35',
#  'mba.52230_den',
#  'drift_36',
#  'mba.52230_aper',
#  'mba.52230',
#  'drift_37',
#  'mba.52230_dex',
#  'drift_38',
#  'mba.52250_den',
#  'drift_39',
#  'mba.52250_aper',
#  'mba.52250',
#  'drift_40',
#  'mba.52250_dex',
#  'drift_41',
#  'mbb.52270_den',
#  'drift_42',
#  'mbb.52270_aper',
#  'mbb.52270',
#  'drift_43',
#  'mbb.52270_dex',
#  'drift_44',
#  'mbb.52290_den',
#  'drift_45',
#  'mbb.52290_aper',
#  'mbb.52290',
#  'drift_46',
#  'mbb.52290_dex',
#  'drift_47',
#  'lsd.52305_aper',
#  'lsd.52305',
#  'drift_48',
#  'mdv.52307_aper',
#  'mdv.52307',
#  'drift_49',
#  'bpv.52308_aper',
#  'bpv.52308',
#  'drift_50',
#  'qd.52310_aper',
#  'qd.52310',
#  'drift_51',
#  'mbb.52330_den',
#  'drift_52',
#  'mbb.52330_aper',
#  'mbb.52330',
#  'drift_53',
#  'mbb.52330_dex',
#  'drift_54',
#  'mbb.52350_den',
#  'drift_55',
#  'mbb.52350_aper',
#  'mbb.52350',
#  'drift_56',
#  'mbb.52350_dex',
#  'drift_57',
#  'mba.52370_den',
#  'drift_58',
#  'mba.52370_aper',
#  'mba.52370',
#  'drift_59',
#  'mba.52370_dex',
#  'drift_60',
#  'mba.52390_den',
#  'drift_61',
#  'mba.52390_aper',
#  'mba.52390',
#  'drift_62',
#  'mba.52390_dex',
#  'drift_63',
#  'lse.52402_aper',
#  'lse.52402',
#  'drift_64',
#  'lsf.52405_aper',
#  'lsf.52405',
#  'drift_65',
#  'mdh.52407_aper',
#  'mdh.52407',
#  'drift_66',
#  'bph.52408_aper',
#  'bph.52408',
#  'drift_67',
#  'qf.52410_aper',
#  'qf.52410',
#  'drift_68',
#  'mba.52430_den',
#  'drift_69',
#  'mba.52430_aper',
#  'mba.52430',
#  'drift_70',
#  'mba.52430_dex',
#  'drift_71',
#  'mba.52450_den',
#  'drift_72',
#  'mba.52450_aper',
#  'mba.52450',
#  'drift_73',
#  'mba.52450_dex',
#  'drift_74',
#  'mbb.52470_den',
#  'drift_75',
#  'mbb.52470_aper',
#  'mbb.52470',
#  'drift_76',
#  'mbb.52470_dex',
#  'drift_77',
#  'mbb.52490_den',
#  'drift_78',
#  'mbb.52490_aper',
#  'mbb.52490',
#  'drift_79',
#  'mbb.52490_dex',
#  'drift_80',
#  'lsd.52505_aper',
#  'lsd.52505',
#  'drift_81',
#  'mdv.52507_aper',
#  'mdv.52507',
#  'drift_82',
#  'bpv.52508_aper',
#  'bpv.52508',
#  'drift_83',
#  'qd.52510_aper',
#  'qd.52510',
#  'drift_84',
#  'mbb.52530_den',
#  'drift_85',
#  'mbb.52530_aper',
#  'mbb.52530',
#  'drift_86',
#  'mbb.52530_dex',
#  'drift_87',
#  'mbb.52550_den',
#  'drift_88',
#  'mbb.52550_aper',
#  'mbb.52550',
#  'drift_89',
#  'mbb.52550_dex',
#  'drift_90',
#  'mba.52570_den',
#  'drift_91',
#  'mba.52570_aper',
#  'mba.52570',
#  'drift_92',
#  'mba.52570_dex',
#  'drift_93',
#  'mba.52590_den',
#  'drift_94',
#  'mba.52590_aper',
#  'mba.52590',
#  'drift_95',
#  'mba.52590_dex',
#  'drift_96',
#  'lof.52602_aper',
#  'lof.52602',
#  'drift_97',
#  'lsf.52605_aper',
#  'lsf.52605',
#  'drift_98',
#  'mdh.52607_aper',
#  'mdh.52607',
#  'drift_99',
#  'bph.52608_aper',
#  'bph.52608',
#  'drift_100',
#  'qf.52610_aper',
#  'qf.52610',
#  'drift_101',
#  'mba.52630_den',
#  'drift_102',
#  'mba.52630_aper',
#  'mba.52630',
#  'drift_103',
#  'mba.52630_dex',
#  'drift_104',
#  'mba.52650_den',
#  'drift_105',
#  'mba.52650_aper',
#  'mba.52650',
#  'drift_106',
#  'mba.52650_dex',
#  'drift_107',
#  'mbb.52670_den',
#  'drift_108',
#  'mbb.52670_aper',
#  'mbb.52670',
#  'drift_109',
#  'mbb.52670_dex',
#  'drift_110',
#  'mbb.52690_den',
#  'drift_111',
#  'mbb.52690_aper',
#  'mbb.52690',
#  'drift_112',
#  'mbb.52690_dex',
#  'drift_113',
#  'lod.52702_aper',
#  'lod.52702',
#  'drift_114',
#  'lsd.52705_aper',
#  'lsd.52705',
#  'drift_115',
#  'mdv.52707_aper',
#  'mdv.52707',
#  'drift_116',
#  'bpv.52708_aper',
#  'bpv.52708',
#  'drift_117',
#  'qd.52710_aper',
#  'qd.52710',
#  'drift_118',
#  'mbb.52730_den',
#  'drift_119',
#  'mbb.52730_aper',
#  'mbb.52730',
#  'drift_120',
#  'mbb.52730_dex',
#  'drift_121',
#  'mbb.52750_den',
#  'drift_122',
#  'mbb.52750_aper',
#  'mbb.52750',
#  'drift_123',
#  'mbb.52750_dex',
#  'drift_124',
#  'mba.52770_den',
#  'drift_125',
#  'mba.52770_aper',
#  'mba.52770',
#  'drift_126',
#  'mba.52770_dex',
#  'drift_127',
#  'mba.52790_den',
#  'drift_128',
#  'mba.52790_aper',
#  'mba.52790',
#  'drift_129',
#  'mba.52790_dex',
#  'drift_130',
#  'lof.52802_aper',
#  'lof.52802',
#  'drift_131',
#  'mdh.52807_aper',
#  'mdh.52807',
#  'drift_132',
#  'bph.52808_aper',
#  'bph.52808',
#  'drift_133',
#  'qf.52810_aper',
#  'qf.52810',
#  'drift_134',
#  'mba.52830_den',
#  'drift_135',
#  'mba.52830_aper',
#  'mba.52830',
#  'drift_136',
#  'mba.52830_dex',
#  'drift_137',
#  'mba.52850_den',
#  'drift_138',
#  'mba.52850_aper',
#  'mba.52850',
#  'drift_139',
#  'mba.52850_dex',
#  'drift_140',
#  'mbb.52870_den',
#  'drift_141',
#  'mbb.52870_aper',
#  'mbb.52870',
#  'drift_142',
#  'mbb.52870_dex',
#  'drift_143',
#  'mbb.52890_den',
#  'drift_144',
#  'mbb.52890_aper',
#  'mbb.52890',
#  'drift_145',
#  'mbb.52890_dex',
#  'drift_146',
#  'lqsa.52902_aper',
#  'lqsa.52902',
#  'drift_147',
#  'mdv.52907_aper',
#  'mdv.52907',
#  'drift_148',
#  'bpv.52908_aper',
#  'bpv.52908',
#  'drift_149',
#  'qd.52910_aper',
#  'qd.52910',
#  'drift_150',
#  'mbb.52930_den',
#  'drift_151',
#  'mbb.52930_aper',
#  'mbb.52930',
#  'drift_152',
#  'mbb.52930_dex',
#  'drift_153',
#  'mbb.52950_den',
#  'drift_154',
#  'mbb.52950_aper',
#  'mbb.52950',
#  'drift_155',
#  'mbb.52950_dex',
#  'drift_156',
#  'mba.52970_den',
#  'drift_157',
#  'mba.52970_aper',
#  'mba.52970',
#  'drift_158',
#  'mba.52970_dex',
#  'drift_159',
#  'mba.52990_den',
#  'drift_160',
#  'mba.52990_aper',
#  'mba.52990',
#  'drift_161',
#  'mba.52990_dex',
#  'drift_162',
#  'lof.53002_aper',
#  'lof.53002',
#  'drift_163',
#  'mdh.53007_aper',
#  'mdh.53007',
#  'drift_164',
#  'bph.53008_aper',
#  'bph.53008',
#  'drift_165',
#  'qf.53010_aper',
#  'qf.53010',
#  'drift_166',
#  'mba.53030_den',
#  'drift_167',
#  'mba.53030_aper',
#  'mba.53030',
#  'drift_168',
#  'mba.53030_dex',
#  'drift_169',
#  'mba.53050_den',
#  'drift_170',
#  'mba.53050_aper',
#  'mba.53050',
#  'drift_171',
#  'mba.53050_dex',
#  'drift_172',
#  'mbb.53070_den',
#  'drift_173',
#  'mbb.53070_aper',
#  'mbb.53070',
#  'drift_174',
#  'mbb.53070_dex',
#  'drift_175',
#  'mbb.53090_den',
#  'drift_176',
#  'mbb.53090_aper',
#  'mbb.53090',
#  'drift_177',
#  'mbb.53090_dex',
#  'drift_178',
#  'mdv.53107_aper',
#  'mdv.53107',
#  'drift_179',
#  'bpv.53108_aper',
#  'bpv.53108',
#  'drift_180',
#  'qd.53110_aper',
#  'qd.53110',
#  'drift_181',
#  'mbb.53130_den',
#  'drift_182',
#  'mbb.53130_aper',
#  'mbb.53130',
#  'drift_183',
#  'mbb.53130_dex',
#  'drift_184',
#  'mbb.53150_den',
#  'drift_185',
#  'mbb.53150_aper',
#  'mbb.53150',
#  'drift_186',
#  'mbb.53150_dex',
#  'drift_187',
#  'mba.53170_den',
#  'drift_188',
#  'mba.53170_aper',
#  'mba.53170',
#  'drift_189',
#  'mba.53170_dex',
#  'drift_190',
#  'mba.53190_den',
#  'drift_191',
#  'mba.53190_aper',
#  'mba.53190',
#  'drift_192',
#  'mba.53190_dex',
#  'drift_193',
#  'lsf.53205_aper',
#  'lsf.53205',
#  'drift_194',
#  'mdh.53207_aper',
#  'mdh.53207',
#  'drift_195',
#  'bph.53208_aper',
#  'bph.53208',
#  'drift_196',
#  'qf.53210_aper',
#  'qf.53210',
#  'drift_197',
#  'mba.53230_den',
#  'drift_198',
#  'mba.53230_aper',
#  'mba.53230',
#  'drift_199',
#  'mba.53230_dex',
#  'drift_200',
#  'mba.53250_den',
#  'drift_201',
#  'mba.53250_aper',
#  'mba.53250',
#  'drift_202',
#  'mba.53250_dex',
#  'drift_203',
#  'mbb.53270_den',
#  'drift_204',
#  'mbb.53270_aper',
#  'mbb.53270',
#  'drift_205',
#  'mbb.53270_dex',
#  'drift_206',
#  'mbb.53290_den',
#  'drift_207',
#  'mbb.53290_aper',
#  'mbb.53290',
#  'drift_208',
#  'mbb.53290_dex',
#  'drift_209',
#  'lod.53302_aper',
#  'lod.53302',
#  'drift_210',
#  'mdv.53307_aper',
#  'mdv.53307',
#  'drift_211',
#  'bpv.53308_aper',
#  'bpv.53308',
#  'drift_212',
#  'qd.53310_aper',
#  'qd.53310',
#  'drift_213',
#  'mbb.53330_den',
#  'drift_214',
#  'mbb.53330_aper',
#  'mbb.53330',
#  'drift_215',
#  'mbb.53330_dex',
#  'drift_216',
#  'mbb.53350_den',
#  'drift_217',
#  'mbb.53350_aper',
#  'mbb.53350',
#  'drift_218',
#  'mbb.53350_dex',
#  'drift_219',
#  'mba.53370_den',
#  'drift_220',
#  'mba.53370_aper',
#  'mba.53370',
#  'drift_221',
#  'mba.53370_dex',
#  'drift_222',
#  'mba.53390_den',
#  'drift_223',
#  'mba.53390_aper',
#  'mba.53390',
#  'drift_224',
#  'mba.53390_dex',
#  'drift_225',
#  'qecd.53402',
#  'drift_226',
#  'mdh.53407_aper',
#  'mdh.53407',
#  'drift_227',
#  'bph.53408_aper',
#  'bph.53408',
#  'drift_228',
#  'qf.53410_aper',
#  'qf.53410',
#  'drift_229',
#  'mba.53430_den',
#  'drift_230',
#  'mba.53430_aper',
#  'mba.53430',
#  'drift_231',
#  'mba.53430_dex',
#  'drift_232',
#  'mba.53450_den',
#  'drift_233',
#  'mba.53450_aper',
#  'mba.53450',
#  'drift_234',
#  'mba.53450_dex',
#  'drift_235',
#  'mbb.53470_den',
#  'drift_236',
#  'mbb.53470_aper',
#  'mbb.53470',
#  'drift_237',
#  'mbb.53470_dex',
#  'drift_238',
#  'mbb.53490_den',
#  'drift_239',
#  'mbb.53490_aper',
#  'mbb.53490',
#  'drift_240',
#  'mbb.53490_dex',
#  'drift_241',
#  'lod.53502_aper',
#  'lod.53502',
#  'drift_242',
#  'lsd.53505_aper',
#  'lsd.53505',
#  'drift_243',
#  'mdv.53507_aper',
#  'mdv.53507',
#  'drift_244',
#  'bpv.53508_aper',
#  'bpv.53508',
#  'drift_245',
#  'qd.53510_aper',
#  'qd.53510',
#  'drift_246',
#  'mbb.53530_den',
#  'drift_247',
#  'mbb.53530_aper',
#  'mbb.53530',
#  'drift_248',
#  'mbb.53530_dex',
#  'drift_249',
#  'mbb.53550_den',
#  'drift_250',
#  'mbb.53550_aper',
#  'mbb.53550',
#  'drift_251',
#  'mbb.53550_dex',
#  'drift_252',
#  'mba.53570_den',
#  'drift_253',
#  'mba.53570_aper',
#  'mba.53570',
#  'drift_254',
#  'mba.53570_dex',
#  'drift_255',
#  'mba.53590_den',
#  'drift_256',
#  'mba.53590_aper',
#  'mba.53590',
#  'drift_257',
#  'mba.53590_dex',
#  'drift_258',
#  'loen.53602_aper',
#  'loen.53602',
#  'drift_259',
#  'lsf.53605_aper',
#  'lsf.53605',
#  'drift_260',
#  'mdh.53607_aper',
#  'mdh.53607',
#  'drift_261',
#  'bph.53608_aper',
#  'bph.53608',
#  'drift_262',
#  'qf.60010_aper',
#  'qf.60010',
#  'drift_263',
#  'mba.60030_den',
#  'drift_264',
#  'mba.60030_aper',
#  'mba.60030',
#  'drift_265',
#  'mba.60030_dex',
#  'drift_266',
#  'mba.60050_den',
#  'drift_267',
#  'mba.60050_aper',
#  'mba.60050',
#  'drift_268',
#  'mba.60050_dex',
#  'drift_269',
#  'mbb.60070_den',
#  'drift_270',
#  'mbb.60070_aper',
#  'mbb.60070',
#  'drift_271',
#  'mbb.60070_dex',
#  'drift_272',
#  'mbb.60090_den',
#  'drift_273',
#  'mbb.60090_aper',
#  'mbb.60090',
#  'drift_274',
#  'mbb.60090_dex',
#  'drift_275',
#  'lsd.60105_aper',
#  'lsd.60105',
#  'drift_276',
#  'mdv.60107_aper',
#  'mdv.60107',
#  'drift_277',
#  'bpv.60108_aper',
#  'bpv.60108',
#  'drift_278',
#  'qd.60110_aper',
#  'qd.60110',
#  'drift_279',
#  'mbb.60130_den',
#  'drift_280',
#  'mbb.60130_aper',
#  'mbb.60130',
#  'drift_281',
#  'mbb.60130_dex',
#  'drift_282',
#  'mbb.60150_den',
#  'drift_283',
#  'mbb.60150_aper',
#  'mbb.60150',
#  'drift_284',
#  'mbb.60150_dex',
#  'drift_285',
#  'mba.60170_den',
#  'drift_286',
#  'mba.60170_aper',
#  'mba.60170',
#  'drift_287',
#  'mba.60170_dex',
#  'drift_288',
#  'mba.60190_den',
#  'drift_289',
#  'mba.60190_aper',
#  'mba.60190',
#  'drift_290',
#  'mba.60190_dex',
#  'drift_291',
#  'lsf.60205_aper',
#  'lsf.60205',
#  'drift_292',
#  'mdh.60207_aper',
#  'mdh.60207',
#  'drift_293',
#  'bph.60208_aper',
#  'bph.60208',
#  'drift_294',
#  'qf.60210_aper',
#  'qf.60210',
#  'drift_295',
#  'mba.60230_den',
#  'drift_296',
#  'mba.60230_aper',
#  'mba.60230',
#  'drift_297',
#  'mba.60230_dex',
#  'drift_298',
#  'mba.60250_den',
#  'drift_299',
#  'mba.60250_aper',
#  'mba.60250',
#  'drift_300',
#  'mba.60250_dex',
#  'drift_301',
#  'mbb.60270_den',
#  'drift_302',
#  'mbb.60270_aper',
#  'mbb.60270',
#  'drift_303',
#  'mbb.60270_dex',
#  'drift_304',
#  'mbb.60290_den',
#  'drift_305',
#  'mbb.60290_aper',
#  'mbb.60290',
#  'drift_306',
#  'mbb.60290_dex',
#  'drift_307',
#  'qe.60302',
#  'drift_308',
#  'lsd.60305_aper',
#  'lsd.60305',
#  'drift_309',
#  'mdv.60307_aper',
#  'mdv.60307',
#  'drift_310',
#  'bpv.60308_aper',
#  'bpv.60308',
#  'drift_311',
#  'qd.60310_aper',
#  'qd.60310',
#  'drift_312',
#  'mbb.60330_den',
#  'drift_313',
#  'mbb.60330_aper',
#  'mbb.60330',
#  'drift_314',
#  'mbb.60330_dex',
#  'drift_315',
#  'mbb.60350_den',
#  'drift_316',
#  'mbb.60350_aper',
#  'mbb.60350',
#  'drift_317',
#  'mbb.60350_dex',
#  'drift_318',
#  'mba.60370_den',
#  'drift_319',
#  'mba.60370_aper',
#  'mba.60370',
#  'drift_320',
#  'mba.60370_dex',
#  'drift_321',
#  'mba.60390_den',
#  'drift_322',
#  'mba.60390_aper',
#  'mba.60390',
#  'drift_323',
#  'mba.60390_dex',
#  'drift_324',
#  'qe.60402',
#  'drift_325',
#  'mdh.60407_aper',
#  'mdh.60407',
#  'drift_326',
#  'bph.60408_aper',
#  'bph.60408',
#  'drift_327',
#  'qf.60410_aper',
#  'qf.60410',
#  'drift_328',
#  'mba.60430_den',
#  'drift_329',
#  'mba.60430_aper',
#  'mba.60430',
#  'drift_330',
#  'mba.60430_dex',
#  'drift_331',
#  'mba.60450_den',
#  'drift_332',
#  'mba.60450_aper',
#  'mba.60450',
#  'drift_333',
#  'mba.60450_dex',
#  'drift_334',
#  'mbb.60470_den',
#  'drift_335',
#  'mbb.60470_aper',
#  'mbb.60470',
#  'drift_336',
#  'mbb.60470_dex',
#  'drift_337',
#  'mbb.60490_den',
#  'drift_338',
#  'mbb.60490_aper',
#  'mbb.60490',
#  'drift_339',
#  'mbb.60490_dex',
#  'drift_340',
#  'qe.60502',
#  'drift_341',
#  'mdv.60507_aper',
#  'mdv.60507',
#  'drift_342',
#  'bpv.60508_aper',
#  'bpv.60508',
#  'drift_343',
#  'qd.60510_aper',
#  'qd.60510',
#  'drift_344',
#  'mbb.60530_den',
#  'drift_345',
#  'mbb.60530_aper',
#  'mbb.60530',
#  'drift_346',
#  'mbb.60530_dex',
#  'drift_347',
#  'mbb.60550_den',
#  'drift_348',
#  'mbb.60550_aper',
#  'mbb.60550',
#  'drift_349',
#  'mbb.60550_dex',
#  'drift_350',
#  'mba.60570_den',
#  'drift_351',
#  'mba.60570_aper',
#  'mba.60570',
#  'drift_352',
#  'mba.60570_dex',
#  'drift_353',
#  'mba.60590_den',
#  'drift_354',
#  'mba.60590_aper',
#  'mba.60590',
#  'drift_355',
#  'mba.60590_dex',
#  'drift_356',
#  'qe.60602',
#  'drift_357',
#  'mdh.60607_aper',
#  'mdh.60607',
#  'drift_358',
#  'bph.60608_aper',
#  'bph.60608',
#  'drift_359',
#  'qf.60610_aper',
#  'qf.60610',
#  'drift_360',
#  'mba.60630_den',
#  'drift_361',
#  'mba.60630_aper',
#  'mba.60630',
#  'drift_362',
#  'mba.60630_dex',
#  'drift_363',
#  'mba.60650_den',
#  'drift_364',
#  'mba.60650_aper',
#  'mba.60650',
#  'drift_365',
#  'mba.60650_dex',
#  'drift_366',
#  'mbb.60670_den',
#  'drift_367',
#  'mbb.60670_aper',
#  'mbb.60670',
#  'drift_368',
#  'mbb.60670_dex',
#  'drift_369',
#  'mbb.60690_den',
#  'drift_370',
#  'mbb.60690_aper',
#  'mbb.60690',
#  'drift_371',
#  'mbb.60690_dex',
#  'drift_372',
#  'lod.60702_aper',
#  'lod.60702',
#  'drift_373',
#  'mdv.60707_aper',
#  'mdv.60707',
#  'drift_374',
#  'bpv.60708_aper',
#  'bpv.60708',
#  'drift_375',
#  'qd.60710_aper',
#  'qd.60710',
#  'drift_376',
#  'mbb.60730_den',
#  'drift_377',
#  'mbb.60730_aper',
#  'mbb.60730',
#  'drift_378',
#  'mbb.60730_dex',
#  'drift_379',
#  'mbb.60750_den',
#  'drift_380',
#  'mbb.60750_aper',
#  'mbb.60750',
#  'drift_381',
#  'mbb.60750_dex',
#  'drift_382',
#  'mba.60770_den',
#  'drift_383',
#  'mba.60770_aper',
#  'mba.60770',
#  'drift_384',
#  'mba.60770_dex',
#  'drift_385',
#  'mba.60790_den',
#  'drift_386',
#  'mba.60790_aper',
#  'mba.60790',
#  'drift_387',
#  'mba.60790_dex',
#  'drift_388',
#  'lof.60802_aper',
#  'lof.60802',
#  'drift_389',
#  'lsf.60805_aper',
#  'lsf.60805',
#  'drift_390',
#  'mdh.60807_aper',
#  'mdh.60807',
#  'drift_391',
#  'bph.60808_aper',
#  'bph.60808',
#  'drift_392',
#  'qf.60810_aper',
#  'qf.60810',
#  'drift_393',
#  'mba.60830_den',
#  'drift_394',
#  'mba.60830_aper',
#  'mba.60830',
#  'drift_395',
#  'mba.60830_dex',
#  'drift_396',
#  'mba.60850_den',
#  'drift_397',
#  'mba.60850_aper',
#  'mba.60850',
#  'drift_398',
#  'mba.60850_dex',
#  ...)

# %%
line.elements  # Element objects
# Out:
# (<xtrack.beam_elements.elements.Marker at 0x7f2e5b925880>,
#  <xtrack.beam_elements.elements.Marker at 0x7f2ed1d5a1c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f
>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2b4f0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df2b580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df2b670>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2b6a0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df2b7c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2b970>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df2ba00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2ba60>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df2bb80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df2bd30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2bd60>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df2be80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2e070>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2e100>,
#  <xtrack.beam_elements.apertures.LimitEllipse at 0x7f2e8df2e1c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df2e2b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2e2e0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df2e400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2e5b0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df2e640>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df2e730>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2e760>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df2e880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2ea30>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df2eac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2ebb0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df2ec40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df2ed30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2ed60>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df2ee80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2f070>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df2f100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2f1f0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df2f280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df2f370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2f3a0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df2f4c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2f670>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df2f700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2f7f0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df2f880>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df2f970>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2f9a0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df2fac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2fc70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df2fd00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df2fd60>,
#  <xtrack.beam_elements.apertures.LimitEllipse at 0x7f2e8df2fe80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df30070>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df300a0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df301c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df30370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df30400>,
#  <xtrack.beam_elements.apertures.LimitEllipse at 0x7f2e8df304c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df305b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df305e0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df30700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df308b0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df30940>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df30a30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df30a60>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df30b80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df30d30>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df30dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df30eb0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df30f40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df32070>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df320a0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df321c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df32370>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df32400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df324f0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df32580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df32670>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df326a0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df327c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df32970>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df32a00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df32af0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df32b80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df32c70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df32ca0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df32dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df32f70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df33040>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df330a0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df331c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df33370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df333a0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df334c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df33670>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df33700>,
#  <xtrack.beam_elements.apertures.LimitEllipse at 0x7f2e8df338b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df33a30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df33a60>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df33b80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df33d30>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df33dc0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df33eb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df33ee0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df337c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df88eb0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df38040>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df381f0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df38280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df38370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df383a0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df384c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df38670>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df38700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df387f0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df38880>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df38970>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df389a0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df38ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df38c70>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df38d00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df38df0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df38e80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df38f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df38fa0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df39100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df392b0>,
#  <xtrack.beam_elements.apertures.LimitEllipse at 0x7f2e8df39340>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df39430>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df39460>,
#  <xtrack.beam_elements.apertures.LimitEllipse at 0x7f2e8df39580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df39730>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df39760>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df39880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df39a30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df39ac0>,
#  <xtrack.beam_elements.apertures.LimitEllipse at 0x7f2e8df39b80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df39c70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df39ca0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df39dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df39f70>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df3a040>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df3a130>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3a160>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df3a280>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3a430>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df3a4c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3a5b0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df3a640>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df3a730>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3a760>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df3a880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3aa30>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df3aac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3abb0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df3ac40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df3ad30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3ad60>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df3ae80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3d070>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df3d100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3d1f0>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df3d280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df3d370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3d3a0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df3d4c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3d670>,
#  <xtrack.beam_elements.apertures.LimitEllipse at 0x7f2e8df3d700>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df3d7f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3d820>,
#  <xtrack.beam_elements.apertures.LimitEllipse at 0x7f2e8df3d940>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df3daf0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3db20>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df3dc40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df3ddf0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df3de20>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df3df70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df40130>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df401c0>,
#  <xtrack.beam_elements.apertures.LimitEllipse at 0x7f2e8df40280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df40370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df403a0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df404c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df40670>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df40700>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df407f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df40820>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df40940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df40af0>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df40b80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df40c70>,
#  <xtrack.beam_elements.apertures.LimitRect at 0x7f2e8df40d00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f2e8df40df0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f2e8df40e20>,
#  <xtrack.beam_elements.elements.DipoleEdge at 0x7f2e8df40f70>,
#  ...)

# %%
line['mbb.52070']  # A bending magnet

# %% [markdown]
# ### Access the properties of individual elements

# %%
line['mbb.52070'].to_dict()  # We can view its properties
# Out:
# {'__class__': 'Multipole',
#  'order': 0,
#  'inv_factorial_order': 1.0,
#  'length': 6.26001860278045,
#  'hxl': 0.008445141542,
#  'hyl': 0.0,
#  'radiation_flag': 0,
#  'knl': array([0.00844514]),
#  'ksl': array([0.])}

# %%
# A quadrupole
line['qf.52010']
line['qf.52010'].to_dict()
# Out:
# {'__class__': 'Multipole',
#  'order': 1,
#  'inv_factorial_order': 1.0,
#  'length': 3.085,
#  'hxl': 0.0,
#  'hyl': 0.0,
#  'radiation_flag': 0,
#  'knl': array([0.       , 0.0345839]),
#  'ksl': array([0., 0.])}

# %% [markdown]
# ### Twiss
#
# Compute orbit, optics and other quantities of interest.

# %%
# Compute the twiss for the beamline
line.particle_ref = xp.Particles(mass0=xp.PROTON_MASS_EV, p0c=26e9)
tw = line.twiss()

# %%
fig, (spbet, spdx) = plt.subplots(nrows=2, ncols=1, sharex=True)
spbet.plot(tw.s, tw.betx)
spbet.plot(tw.s, tw.bety)
spbet.set_ylim(bottom=0)
spdx.plot(tw.s, tw.dx)
spdx.plot(tw.s, tw.dy)

spbet.set_ylabel(r'$\beta_{x,y}$ [m]')
spdx.set_ylabel(r"$D_{x,y}$")


fig.suptitle(
    r'$q_x$ = ' f'{tw["qx"]:.5f}' r' $q_y$ = ' f'{tw["qy"]:.5f}' '\n'
    r"$Q'_x$ = " f'{tw["dqx"]:.2f}' r" $Q'_y$ = " f'{tw["dqy"]:.2f}'
    r' $\gamma_{tr}$ = '  f'{1/np.sqrt(tw["momentum_compaction_factor"]):.2f}'
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 0.98, "$q_x$ = 20.15000 $q_y$ = 20.25000\n$Q'_x$ = -1.32 $Q'_y$ = -0.72 $\\gamma_{tr}$ = 18.01")

# %% [markdown]
# ### Measure the tune

# %%
num_turns = 500

p_co = tw.particle_on_co.copy()

line.track(p_co, num_turns=num_turns, turn_by_turn_monitor=True)
mon_co = line.record_last_track

p1 = tw.particle_on_co.copy()
p1.x += 0.1e-3
p1.y += 0.2e-3
line.track(p1, num_turns=num_turns, turn_by_turn_monitor=True)
mon1 = line.record_last_track

# %%
# Plot turn-by-turn data
fig, (spx, spy) = plt.subplots(nrows=2, ncols=1, sharex=True)
fig.suptitle('Turn-by-turn data')
spx.plot(mon_co.x.T)
spx.plot(mon1.x.T)
spy.plot(mon_co.y.T)
spy.plot(mon1.y.T)
spy.set_xlabel('Turn')
spx.set_ylabel('x [m]')
spy.set_ylabel('y [m]')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0, 0.5, 'y [m]')

# %%
# Plot the transverse spectrum
fig, (spx, spy) = plt.subplots(nrows=2, ncols=1, sharex=True)
fig.suptitle('Transverse spectrum')
freq_axis = np.fft.rfftfreq(n=num_turns)
spx.plot(freq_axis, np.abs(np.fft.rfft(mon1.x[0, :])))
spy.plot(freq_axis, np.abs(np.fft.rfft(mon1.y[0, :])))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Consistent with the twiss

# %%
tw.qx, tw.qy
# Out:
# (20.15000024623154, 20.25000000092244)

# %% [markdown]
# ### Survey

# %%
# Run the survey
sv = line.survey(element0=0)

# %%
# See the whole ring
fig, ax = plt.subplots()
fig.suptitle('SPS Ring')
ax.set_box_aspect(1)
ax.plot(sv.Z, sv.X, label='x', linestyle='--', color='b')

ax.plot(sv.Z, sv.X + tw.x, label='x', linestyle='-', color='b')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.trapz(tw.betx, tw.s)/tw.circumference  # measure the simulated average beta function
# Out:
# 62.5702959144828

# %%
tw.circumference/2/np.pi/tw.qx  # simplified estimate
# Out:
# 54.590569753176105
