# %%
pip install xsuite
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xsuite in /eos/home-i01/g/giadarol/.local/lib/python3.9/site-packages (0.5.0)
# Requirement already satisfied: xpart in /eos/home-i01/g/giadarol/.local/lib/python3.9/site-packages (from xsuite) (0.14.3)
# Requirement already satisfied: xobjects in /eos/home-i01/g/giadarol/.local/lib/python3.9/site-packages (from xsuite) (0.2.3)
# Requirement already satisfied: xfields in /eos/home-i01/g/giadarol/.local/lib/python3.9/site-packages (from xsuite) (0.11.2)
# Requirement already satisfied: numpy>=1.0 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from xsuite) (1.22.3)
# Requirement already satisfied: xtrack in /eos/home-i01/g/giadarol/.local/lib/python3.9/site-packages (from xsuite) (0.32.1)
# Requirement already satisfied: xdeps in /eos/home-i01/g/giadarol/.local/lib/python3.9/site-packages (from xsuite) (0.0.14)
# Requirement already satisfied: lark in /eos/home-i01/g/giadarol/.local/lib/python3.9/site-packages (from xdeps->xsuite) (1.1.5)
# Requirement already satisfied: scipy in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from xfields->xsuite) (1.8.0)
# Requirement already satisfied: pandas in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from xfields->xsuite) (1.2.2)
# Requirement already satisfied: cffi in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from xobjects->xsuite) (1.14.6)
# Requirement already satisfied: pycparser in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from cffi->xobjects->xsuite) (2.20)
# Requirement already satisfied: python-dateutil>=2.7.3 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from pandas->xfields->xsuite) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from pandas->xfields->xsuite) (2021.1)
# Requirement already satisfied: six>=1.5 in /cvmfs/sft.cern.ch/lcg/views/LCG_102b_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->xfields->xsuite) (1.16.0)
# /bin/bash: xsuite-prebuild: command not found

# %%
# %matplotlib widget
import ipympl

import numpy as np
import matplotlib.pyplot as plt

import xpart as xp
import xtrack as xt

fname_model = './generate_models/lhc_at_collisions.json'

nemitt_x = 2.5e-6
nemitt_y = 2.5e-6

collider = xt.Multiline.from_json(fname_model)
collider.build_trackers()
# Out:
# Done loading line from dict.
# Done loading line from dict.
# Done loading line from dict.
# Done loading line from dict.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.

# %% [markdown]
# ## Exploring the LHC
#
# The two beamlines are accessible through `collider.lhcb1` and `collider.lhcb2`. Some examples on how we can access the elements of the lines.
#
# ### Enumerate elements and their names

# %%
collider.lhcb1.element_names  # Element names
# Out:
# ('ip3',
#  'drift_0',
#  'mcbwv.4r3.b1',
#  'drift_1',
#  'bpmw.4r3.b1',
#  'drift_2',
#  'mqwa.a4r3.b1..1',
#  'drift_3',
#  'mqwa.a4r3.b1..2',
#  'drift_4',
#  'mqwa.a4r3.b1',
#  'drift_5',
#  'mqwa.a4r3.b1..3',
#  'drift_6',
#  'mqwa.a4r3.b1..4',
#  'drift_7',
#  'mqwa.b4r3.b1..1',
#  'drift_8',
#  'mqwa.b4r3.b1..2',
#  'drift_9',
#  'mqwa.b4r3.b1',
#  'drift_10',
#  'mqwa.b4r3.b1..3',
#  'drift_11',
#  'mqwa.b4r3.b1..4',
#  'drift_12',
#  'mqwb.4r3.b1..1',
#  'drift_13',
#  'mqwb.4r3.b1..2',
#  'drift_14',
#  'mqwb.4r3.b1',
#  'drift_15',
#  'mqwb.4r3.b1..3',
#  'drift_16',
#  'mqwb.4r3.b1..4',
#  'drift_17',
#  'mqwa.c4r3.b1..1',
#  'drift_18',
#  'mqwa.c4r3.b1..2',
#  'drift_19',
#  'mqwa.c4r3.b1',
#  'drift_20',
#  'mqwa.c4r3.b1..3',
#  'drift_21',
#  'mqwa.c4r3.b1..4',
#  'drift_22',
#  'mqwa.d4r3.b1..1',
#  'drift_23',
#  'mqwa.d4r3.b1..2',
#  'drift_24',
#  'mqwa.d4r3.b1',
#  'drift_25',
#  'mqwa.d4r3.b1..3',
#  'drift_26',
#  'mqwa.d4r3.b1..4',
#  'drift_27',
#  'tcsg.4r3.b1',
#  'drift_28',
#  'mqwa.e4r3.b1..1',
#  'drift_29',
#  'mqwa.e4r3.b1..2',
#  'drift_30',
#  'mqwa.e4r3.b1',
#  'drift_31',
#  'mqwa.e4r3.b1..3',
#  'drift_32',
#  'mqwa.e4r3.b1..4',
#  'drift_33',
#  'bpmwe.4r3.b1',
#  'drift_34',
#  'tcsg.a5r3.b1',
#  'drift_35',
#  'tcsg.b5r3.b1',
#  'drift_36',
#  'tcla.a5r3.b1',
#  'drift_37',
#  'tcla.b5r3.b1',
#  'drift_38',
#  'mcbwh.5r3.b1',
#  'drift_39',
#  'bpmw.5r3.b1',
#  'drift_40',
#  'mqwa.a5r3.b1..1',
#  'drift_41',
#  'mqwa.a5r3.b1..2',
#  'drift_42',
#  'mqwa.a5r3.b1',
#  'drift_43',
#  'mqwa.a5r3.b1..3',
#  'drift_44',
#  'mqwa.a5r3.b1..4',
#  'drift_45',
#  'mqwa.b5r3.b1..1',
#  'drift_46',
#  'mqwa.b5r3.b1..2',
#  'drift_47',
#  'mqwa.b5r3.b1',
#  'drift_48',
#  'mqwa.b5r3.b1..3',
#  'drift_49',
#  'mqwa.b5r3.b1..4',
#  'drift_50',
#  'mqwb.5r3.b1..1',
#  'drift_51',
#  'mqwb.5r3.b1..2',
#  'drift_52',
#  'mqwb.5r3.b1',
#  'drift_53',
#  'mqwb.5r3.b1..3',
#  'drift_54',
#  'mqwb.5r3.b1..4',
#  'drift_55',
#  'mqwa.c5r3.b1..1',
#  'drift_56',
#  'mqwa.c5r3.b1..2',
#  'drift_57',
#  'mqwa.c5r3.b1',
#  'drift_58',
#  'mqwa.c5r3.b1..3',
#  'drift_59',
#  'mqwa.c5r3.b1..4',
#  'drift_60',
#  'mqwa.d5r3.b1..1',
#  'drift_61',
#  'mqwa.d5r3.b1..2',
#  'drift_62',
#  'mqwa.d5r3.b1',
#  'drift_63',
#  'mqwa.d5r3.b1..3',
#  'drift_64',
#  'mqwa.d5r3.b1..4',
#  'drift_65',
#  'mqwa.e5r3.b1..1',
#  'drift_66',
#  'mqwa.e5r3.b1..2',
#  'drift_67',
#  'mqwa.e5r3.b1',
#  'drift_68',
#  'mqwa.e5r3.b1..3',
#  'drift_69',
#  'mqwa.e5r3.b1..4',
#  'drift_70',
#  'bpmwj.a5r3.b1',
#  'drift_71',
#  'mbw.a6r3.b1',
#  'drift_72',
#  'mbw.b6r3.b1',
#  'drift_73',
#  'mbw.c6r3.b1',
#  'drift_74',
#  'tcla.6r3.b1',
#  'drift_75',
#  'mbw.d6r3.b1',
#  'drift_76',
#  'mbw.e6r3.b1',
#  'drift_77',
#  'mbw.f6r3.b1',
#  'drift_78',
#  'bpmwc.6r3.b1',
#  'drift_79',
#  'mcbcv.6r3.b1',
#  'drift_80',
#  'mqtlh.a6r3.b1..1',
#  'drift_81',
#  'mqtlh.a6r3.b1',
#  'drift_82',
#  'mqtlh.a6r3.b1..2',
#  'drift_83',
#  'mqtlh.b6r3.b1..1',
#  'drift_84',
#  'mqtlh.b6r3.b1',
#  'drift_85',
#  'mqtlh.b6r3.b1..2',
#  'drift_86',
#  'mqtlh.c6r3.b1..1',
#  'drift_87',
#  'mqtlh.c6r3.b1',
#  'drift_88',
#  'mqtlh.c6r3.b1..2',
#  'drift_89',
#  'mqtlh.d6r3.b1..1',
#  'drift_90',
#  'mqtlh.d6r3.b1',
#  'drift_91',
#  'mqtlh.d6r3.b1..2',
#  'drift_92',
#  'mqtlh.e6r3.b1..1',
#  'drift_93',
#  'mqtlh.e6r3.b1',
#  'drift_94',
#  'mqtlh.e6r3.b1..2',
#  'drift_95',
#  'mqtlh.f6r3.b1..1',
#  'drift_96',
#  'mqtlh.f6r3.b1',
#  'drift_97',
#  'mqtlh.f6r3.b1..2',
#  'drift_98',
#  'bpmr.6r3.b1',
#  'drift_99',
#  'tcla.7r3.b1',
#  'drift_100',
#  'dfbaf.7r3.b1',
#  'drift_101',
#  'bpm_a.7r3.b1',
#  'drift_102',
#  'mq.7r3.b1..1',
#  'drift_103',
#  'mq.7r3.b1',
#  'drift_104',
#  'mq.7r3.b1..2',
#  'drift_105',
#  'mqtli.7r3.b1..1',
#  'drift_106',
#  'mqtli.7r3.b1',
#  'drift_107',
#  'mqtli.7r3.b1..2',
#  'drift_108',
#  'mcbch.7r3.b1',
#  'drift_109',
#  's.ds.r3.b1',
#  'drift_110',
#  'mco.8r3.b1',
#  'drift_111',
#  'mcd.8r3.b1',
#  'drift_112',
#  'mb.a8r3.b1..1',
#  'drift_113',
#  'mb.a8r3.b1',
#  'drift_114',
#  'mb.a8r3.b1..2',
#  'drift_115',
#  'mcs.a8r3.b1',
#  'drift_116',
#  'mb.b8r3.b1..1',
#  'drift_117',
#  'mb.b8r3.b1',
#  'drift_118',
#  'mb.b8r3.b1..2',
#  'drift_119',
#  'mcs.b8r3.b1',
#  'drift_120',
#  'bpm.8r3.b1',
#  'drift_121',
#  'mq.8r3.b1..1',
#  'drift_122',
#  'mq.8r3.b1',
#  'drift_123',
#  'mq.8r3.b1..2',
#  'drift_124',
#  'mqtli.8r3.b1..1',
#  'drift_125',
#  'mqtli.8r3.b1',
#  'drift_126',
#  'mqtli.8r3.b1..2',
#  'drift_127',
#  'mcbcv.8r3.b1',
#  'drift_128',
#  'mco.9r3.b1',
#  'drift_129',
#  'mcd.9r3.b1',
#  'drift_130',
#  'mb.a9r3.b1..1',
#  'drift_131',
#  'mb.a9r3.b1',
#  'drift_132',
#  'mb.a9r3.b1..2',
#  'drift_133',
#  'mcs.a9r3.b1',
#  'drift_134',
#  'mb.b9r3.b1..1',
#  'drift_135',
#  'mb.b9r3.b1',
#  'drift_136',
#  'mb.b9r3.b1..2',
#  'drift_137',
#  'mcs.b9r3.b1',
#  'drift_138',
#  'bpm.9r3.b1',
#  'drift_139',
#  'mq.9r3.b1..1',
#  'drift_140',
#  'mq.9r3.b1',
#  'drift_141',
#  'mq.9r3.b1..2',
#  'drift_142',
#  'mqtli.a9r3.b1..1',
#  'drift_143',
#  'mqtli.a9r3.b1',
#  'drift_144',
#  'mqtli.a9r3.b1..2',
#  'drift_145',
#  'mqtli.b9r3.b1..1',
#  'drift_146',
#  'mqtli.b9r3.b1',
#  'drift_147',
#  'mqtli.b9r3.b1..2',
#  'drift_148',
#  'mcbch.9r3.b1',
#  'drift_149',
#  'mco.10r3.b1',
#  'drift_150',
#  'mcd.10r3.b1',
#  'drift_151',
#  'mb.a10r3.b1..1',
#  'drift_152',
#  'mb.a10r3.b1',
#  'drift_153',
#  'mb.a10r3.b1..2',
#  'drift_154',
#  'mcs.a10r3.b1',
#  'drift_155',
#  'mb.b10r3.b1..1',
#  'drift_156',
#  'mb.b10r3.b1',
#  'drift_157',
#  'mb.b10r3.b1..2',
#  'drift_158',
#  'mcs.b10r3.b1',
#  'drift_159',
#  'bpm.10r3.b1',
#  'drift_160',
#  'mq.10r3.b1..1',
#  'drift_161',
#  'mq.10r3.b1',
#  'drift_162',
#  'mq.10r3.b1..2',
#  'drift_163',
#  'mqtli.10r3.b1..1',
#  'drift_164',
#  'mqtli.10r3.b1',
#  'drift_165',
#  'mqtli.10r3.b1..2',
#  'drift_166',
#  'mcbcv.10r3.b1',
#  'drift_167',
#  'mco.11r3.b1',
#  'drift_168',
#  'mcd.11r3.b1',
#  'drift_169',
#  'mb.a11r3.b1..1',
#  'drift_170',
#  'mb.a11r3.b1',
#  'drift_171',
#  'mb.a11r3.b1..2',
#  'drift_172',
#  'mcs.a11r3.b1',
#  'drift_173',
#  'mb.b11r3.b1..1',
#  'drift_174',
#  'mb.b11r3.b1',
#  'drift_175',
#  'mb.b11r3.b1..2',
#  'drift_176',
#  'mcs.b11r3.b1',
#  'drift_177',
#  'leel.11r3.b1',
#  'drift_178',
#  'bpm.11r3.b1',
#  'drift_179',
#  'mq.11r3.b1..1',
#  'drift_180',
#  'mq.11r3.b1',
#  'drift_181',
#  'mq.11r3.b1..2',
#  'drift_182',
#  'mqtli.11r3.b1..1',
#  'drift_183',
#  'mqtli.11r3.b1',
#  'drift_184',
#  'mqtli.11r3.b1..2',
#  'drift_185',
#  'ms.11r3.b1',
#  'drift_186',
#  'mcbh.11r3.b1',
#  'drift_187',
#  's.arc.34.b1',
#  'drift_188',
#  'mco.a12r3.b1',
#  'drift_189',
#  'mcd.a12r3.b1',
#  'drift_190',
#  'mb.a12r3.b1..1',
#  'drift_191',
#  'mb.a12r3.b1',
#  'drift_192',
#  'mb.a12r3.b1..2',
#  'drift_193',
#  'mcs.a12r3.b1',
#  'drift_194',
#  'mb.b12r3.b1..1',
#  'drift_195',
#  'mb.b12r3.b1',
#  'drift_196',
#  'mb.b12r3.b1..2',
#  'drift_197',
#  'mcs.b12r3.b1',
#  'drift_198',
#  'mco.b12r3.b1',
#  'drift_199',
#  'mcd.b12r3.b1',
#  'drift_200',
#  'mb.c12r3.b1..1',
#  'drift_201',
#  'mb.c12r3.b1',
#  'drift_202',
#  'mb.c12r3.b1..2',
#  'drift_203',
#  'mcs.c12r3.b1',
#  'drift_204',
#  'bpm.12r3.b1',
#  'drift_205',
#  'mqt.12r3.b1..1',
#  'drift_206',
#  'mqt.12r3.b1',
#  'drift_207',
#  'mqt.12r3.b1..2',
#  'drift_208',
#  'mq.12r3.b1..1',
#  'drift_209',
#  'mq.12r3.b1',
#  'drift_210',
#  'mq.12r3.b1..2',
#  'drift_211',
#  'ms.12r3.b1',
#  'drift_212',
#  'mcbv.12r3.b1',
#  'drift_213',
#  'mb.a13r3.b1..1',
#  'drift_214',
#  'mb.a13r3.b1',
#  'drift_215',
#  'mb.a13r3.b1..2',
#  'drift_216',
#  'mcs.a13r3.b1',
#  'drift_217',
#  'mco.13r3.b1',
#  'drift_218',
#  'mcd.13r3.b1',
#  'drift_219',
#  'mb.b13r3.b1..1',
#  'drift_220',
#  'mb.b13r3.b1',
#  'drift_221',
#  'mb.b13r3.b1..2',
#  'drift_222',
#  'mcs.b13r3.b1',
#  'drift_223',
#  'mb.c13r3.b1..1',
#  'drift_224',
#  'mb.c13r3.b1',
#  'drift_225',
#  'mb.c13r3.b1..2',
#  'drift_226',
#  'mcs.c13r3.b1',
#  'drift_227',
#  'bpm.13r3.b1',
#  'drift_228',
#  'mqt.13r3.b1..1',
#  'drift_229',
#  'mqt.13r3.b1',
#  'drift_230',
#  'mqt.13r3.b1..2',
#  'drift_231',
#  'mq.13r3.b1..1',
#  'drift_232',
#  'mq.13r3.b1',
#  'drift_233',
#  'mq.13r3.b1..2',
#  'drift_234',
#  'ms.13r3.b1',
#  'drift_235',
#  'mcbh.13r3.b1',
#  'drift_236',
#  'e.ds.r3.b1',
#  'drift_237',
#  'mco.a14r3.b1',
#  'drift_238',
#  'mcd.a14r3.b1',
#  'drift_239',
#  'mb.a14r3.b1..1',
#  'drift_240',
#  'mb.a14r3.b1',
#  'drift_241',
#  'mb.a14r3.b1..2',
#  'drift_242',
#  'mcs.a14r3.b1',
#  'drift_243',
#  'mb.b14r3.b1..1',
#  'drift_244',
#  'mb.b14r3.b1',
#  'drift_245',
#  'mb.b14r3.b1..2',
#  'drift_246',
#  'mcs.b14r3.b1',
#  'drift_247',
#  'mco.b14r3.b1',
#  'drift_248',
#  'mcd.b14r3.b1',
#  'drift_249',
#  'mb.c14r3.b1..1',
#  'drift_250',
#  'mb.c14r3.b1',
#  'drift_251',
#  'mb.c14r3.b1..2',
#  'drift_252',
#  'mcs.c14r3.b1',
#  'drift_253',
#  'bpm.14r3.b1',
#  'drift_254',
#  'mqt.14r3.b1..1',
#  'drift_255',
#  'mqt.14r3.b1',
#  'drift_256',
#  'mqt.14r3.b1..2',
#  'drift_257',
#  'mq.14r3.b1..1',
#  'drift_258',
#  'mq.14r3.b1',
#  'drift_259',
#  'mq.14r3.b1..2',
#  'drift_260',
#  'ms.14r3.b1',
#  'drift_261',
#  'mcbv.14r3.b1',
#  'drift_262',
#  'mb.a15r3.b1..1',
#  'drift_263',
#  'mb.a15r3.b1',
#  'drift_264',
#  'mb.a15r3.b1..2',
#  'drift_265',
#  'mcs.a15r3.b1',
#  'drift_266',
#  'mco.15r3.b1',
#  'drift_267',
#  'mcd.15r3.b1',
#  'drift_268',
#  'mb.b15r3.b1..1',
#  'drift_269',
#  'mb.b15r3.b1',
#  'drift_270',
#  'mb.b15r3.b1..2',
#  'drift_271',
#  'mcs.b15r3.b1',
#  'drift_272',
#  'mb.c15r3.b1..1',
#  'drift_273',
#  'mb.c15r3.b1',
#  'drift_274',
#  'mb.c15r3.b1..2',
#  'drift_275',
#  'mcs.c15r3.b1',
#  'drift_276',
#  'bpm.15r3.b1',
#  'drift_277',
#  'mqt.15r3.b1..1',
#  'drift_278',
#  'mqt.15r3.b1',
#  'drift_279',
#  'mqt.15r3.b1..2',
#  'drift_280',
#  'mq.15r3.b1..1',
#  'drift_281',
#  'mq.15r3.b1',
#  'drift_282',
#  'mq.15r3.b1..2',
#  'drift_283',
#  'ms.15r3.b1',
#  'drift_284',
#  'mcbh.15r3.b1',
#  'drift_285',
#  'mco.a16r3.b1',
#  'drift_286',
#  'mcd.a16r3.b1',
#  'drift_287',
#  'mb.a16r3.b1..1',
#  'drift_288',
#  'mb.a16r3.b1',
#  'drift_289',
#  'mb.a16r3.b1..2',
#  'drift_290',
#  'mcs.a16r3.b1',
#  'drift_291',
#  'mb.b16r3.b1..1',
#  'drift_292',
#  'mb.b16r3.b1',
#  'drift_293',
#  'mb.b16r3.b1..2',
#  'drift_294',
#  'mcs.b16r3.b1',
#  'drift_295',
#  'mco.b16r3.b1',
#  'drift_296',
#  'mcd.b16r3.b1',
#  'drift_297',
#  'mb.c16r3.b1..1',
#  'drift_298',
#  'mb.c16r3.b1',
#  'drift_299',
#  'mb.c16r3.b1..2',
#  'drift_300',
#  'mcs.c16r3.b1',
#  'drift_301',
#  'bpm.16r3.b1',
#  'drift_302',
#  'mqt.16r3.b1..1',
#  'drift_303',
#  'mqt.16r3.b1',
#  'drift_304',
#  'mqt.16r3.b1..2',
#  'drift_305',
#  'mq.16r3.b1..1',
#  'drift_306',
#  'mq.16r3.b1',
#  'drift_307',
#  'mq.16r3.b1..2',
#  'drift_308',
#  'ms.16r3.b1',
#  'drift_309',
#  'mcbv.16r3.b1',
#  'drift_310',
#  'mb.a17r3.b1..1',
#  'drift_311',
#  'mb.a17r3.b1',
#  'drift_312',
#  'mb.a17r3.b1..2',
#  'drift_313',
#  'mcs.a17r3.b1',
#  'drift_314',
#  'mco.17r3.b1',
#  'drift_315',
#  'mcd.17r3.b1',
#  'drift_316',
#  'mb.b17r3.b1..1',
#  'drift_317',
#  'mb.b17r3.b1',
#  'drift_318',
#  'mb.b17r3.b1..2',
#  'drift_319',
#  'mcs.b17r3.b1',
#  'drift_320',
#  'mb.c17r3.b1..1',
#  'drift_321',
#  'mb.c17r3.b1',
#  'drift_322',
#  'mb.c17r3.b1..2',
#  'drift_323',
#  'mcs.c17r3.b1',
#  'drift_324',
#  'bpm.17r3.b1',
#  'drift_325',
#  'mqt.17r3.b1..1',
#  'drift_326',
#  'mqt.17r3.b1',
#  'drift_327',
#  'mqt.17r3.b1..2',
#  'drift_328',
#  'mq.17r3.b1..1',
#  'drift_329',
#  'mq.17r3.b1',
#  'drift_330',
#  'mq.17r3.b1..2',
#  'drift_331',
#  'ms.17r3.b1',
#  'drift_332',
#  'mcbh.17r3.b1',
#  'drift_333',
#  'mco.a18r3.b1',
#  'drift_334',
#  'mcd.a18r3.b1',
#  'drift_335',
#  'mb.a18r3.b1..1',
#  'drift_336',
#  'mb.a18r3.b1',
#  'drift_337',
#  'mb.a18r3.b1..2',
#  'drift_338',
#  'mcs.a18r3.b1',
#  'drift_339',
#  'mb.b18r3.b1..1',
#  'drift_340',
#  'mb.b18r3.b1',
#  'drift_341',
#  'mb.b18r3.b1..2',
#  'drift_342',
#  'mcs.b18r3.b1',
#  'drift_343',
#  'mco.b18r3.b1',
#  'drift_344',
#  'mcd.b18r3.b1',
#  'drift_345',
#  'mb.c18r3.b1..1',
#  'drift_346',
#  'mb.c18r3.b1',
#  'drift_347',
#  'mb.c18r3.b1..2',
#  'drift_348',
#  'mcs.c18r3.b1',
#  'drift_349',
#  'bpm.18r3.b1',
#  'drift_350',
#  'mqt.18r3.b1..1',
#  'drift_351',
#  'mqt.18r3.b1',
#  'drift_352',
#  'mqt.18r3.b1..2',
#  'drift_353',
#  'mq.18r3.b1..1',
#  'drift_354',
#  'mq.18r3.b1',
#  'drift_355',
#  'mq.18r3.b1..2',
#  'drift_356',
#  'ms.18r3.b1',
#  'drift_357',
#  'mcbv.18r3.b1',
#  'drift_358',
#  'mb.a19r3.b1..1',
#  'drift_359',
#  'mb.a19r3.b1',
#  'drift_360',
#  'mb.a19r3.b1..2',
#  'drift_361',
#  'mcs.a19r3.b1',
#  'drift_362',
#  'mco.19r3.b1',
#  'drift_363',
#  'mcd.19r3.b1',
#  'drift_364',
#  'mb.b19r3.b1..1',
#  'drift_365',
#  'mb.b19r3.b1',
#  'drift_366',
#  'mb.b19r3.b1..2',
#  'drift_367',
#  'mcs.b19r3.b1',
#  'drift_368',
#  'mb.c19r3.b1..1',
#  'drift_369',
#  'mb.c19r3.b1',
#  'drift_370',
#  'mb.c19r3.b1..2',
#  'drift_371',
#  'mcs.c19r3.b1',
#  'drift_372',
#  'bpm.19r3.b1',
#  'drift_373',
#  'mqt.19r3.b1..1',
#  'drift_374',
#  'mqt.19r3.b1',
#  'drift_375',
#  'mqt.19r3.b1..2',
#  'drift_376',
#  'mq.19r3.b1..1',
#  'drift_377',
#  'mq.19r3.b1',
#  'drift_378',
#  'mq.19r3.b1..2',
#  'drift_379',
#  'ms.19r3.b1',
#  'drift_380',
#  'mcbh.19r3.b1',
#  'drift_381',
#  'mco.a20r3.b1',
#  'drift_382',
#  'mcd.a20r3.b1',
#  'drift_383',
#  'mb.a20r3.b1..1',
#  'drift_384',
#  'mb.a20r3.b1',
#  'drift_385',
#  'mb.a20r3.b1..2',
#  'drift_386',
#  'mcs.a20r3.b1',
#  'drift_387',
#  'mb.b20r3.b1..1',
#  'drift_388',
#  'mb.b20r3.b1',
#  'drift_389',
#  'mb.b20r3.b1..2',
#  'drift_390',
#  'mcs.b20r3.b1',
#  'drift_391',
#  'mco.b20r3.b1',
#  'drift_392',
#  'mcd.b20r3.b1',
#  'drift_393',
#  'mb.c20r3.b1..1',
#  'drift_394',
#  'mb.c20r3.b1',
#  'drift_395',
#  'mb.c20r3.b1..2',
#  'drift_396',
#  'mcs.c20r3.b1',
#  'drift_397',
#  'bpm.20r3.b1',
#  'drift_398',
#  'mqt.20r3.b1..1',
#  'drift_399',
#  'mqt.20r3.b1',
#  'drift_400',
#  'mqt.20r3.b1..2',
#  'drift_401',
#  'mq.20r3.b1..1',
#  'drift_402',
#  'mq.20r3.b1',
#  'drift_403',
#  'mq.20r3.b1..2',
#  'drift_404',
#  'ms.20r3.b1',
#  'drift_405',
#  'mcbv.20r3.b1',
#  'drift_406',
#  'mb.a21r3.b1..1',
#  'drift_407',
#  'mb.a21r3.b1',
#  'drift_408',
#  'mb.a21r3.b1..2',
#  'drift_409',
#  'mcs.a21r3.b1',
#  'drift_410',
#  'mco.21r3.b1',
#  'drift_411',
#  'mcd.21r3.b1',
#  'drift_412',
#  'mb.b21r3.b1..1',
#  'drift_413',
#  'mb.b21r3.b1',
#  'drift_414',
#  'mb.b21r3.b1..2',
#  'drift_415',
#  'mcs.b21r3.b1',
#  'drift_416',
#  'mb.c21r3.b1..1',
#  'drift_417',
#  'mb.c21r3.b1',
#  'drift_418',
#  'mb.c21r3.b1..2',
#  'drift_419',
#  'mcs.c21r3.b1',
#  'drift_420',
#  'bpm.21r3.b1',
#  'drift_421',
#  'mqt.21r3.b1..1',
#  'drift_422',
#  'mqt.21r3.b1',
#  'drift_423',
#  'mqt.21r3.b1..2',
#  'drift_424',
#  'mq.21r3.b1..1',
#  'drift_425',
#  'mq.21r3.b1',
#  'drift_426',
#  'mq.21r3.b1..2',
#  'drift_427',
#  'ms.21r3.b1',
#  'drift_428',
#  'mcbh.21r3.b1',
#  'drift_429',
#  'mco.a22r3.b1',
#  'drift_430',
#  'mcd.a22r3.b1',
#  'drift_431',
#  'mb.a22r3.b1..1',
#  'drift_432',
#  'mb.a22r3.b1',
#  'drift_433',
#  'mb.a22r3.b1..2',
#  'drift_434',
#  'mcs.a22r3.b1',
#  'drift_435',
#  'mb.b22r3.b1..1',
#  'drift_436',
#  'mb.b22r3.b1',
#  'drift_437',
#  'mb.b22r3.b1..2',
#  'drift_438',
#  'mcs.b22r3.b1',
#  'drift_439',
#  'mco.b22r3.b1',
#  'drift_440',
#  'mcd.b22r3.b1',
#  'drift_441',
#  'mb.c22r3.b1..1',
#  'drift_442',
#  'mb.c22r3.b1',
#  'drift_443',
#  'mb.c22r3.b1..2',
#  'drift_444',
#  'mcs.c22r3.b1',
#  'drift_445',
#  'bpm.22r3.b1',
#  'drift_446',
#  'mo.22r3.b1',
#  'drift_447',
#  'mq.22r3.b1..1',
#  'drift_448',
#  'mq.22r3.b1',
#  'drift_449',
#  'mq.22r3.b1..2',
#  'drift_450',
#  'ms.22r3.b1',
#  'drift_451',
#  'mcbv.22r3.b1',
#  'drift_452',
#  'mb.a23r3.b1..1',
#  'drift_453',
#  'mb.a23r3.b1',
#  'drift_454',
#  'mb.a23r3.b1..2',
#  'drift_455',
#  'mcs.a23r3.b1',
#  'drift_456',
#  'mco.23r3.b1',
#  'drift_457',
#  'mcd.23r3.b1',
#  'drift_458',
#  'mb.b23r3.b1..1',
#  'drift_459',
#  'mb.b23r3.b1',
#  'drift_460',
#  'mb.b23r3.b1..2',
#  'drift_461',
#  'mcs.b23r3.b1',
#  'drift_462',
#  'mb.c23r3.b1..1',
#  'drift_463',
#  'mb.c23r3.b1',
#  'drift_464',
#  'mb.c23r3.b1..2',
#  'drift_465',
#  'mcs.c23r3.b1',
#  'drift_466',
#  'bpm.23r3.b1',
#  'drift_467',
#  'mqs.23r3.b1',
#  'drift_468',
#  'mq.23r3.b1..1',
#  'drift_469',
#  'mq.23r3.b1',
#  'drift_470',
#  'mq.23r3.b1..2',
#  'drift_471',
#  'ms.23r3.b1',
#  'drift_472',
#  'mcbh.23r3.b1',
#  'drift_473',
#  'mco.a24r3.b1',
#  'drift_474',
#  'mcd.a24r3.b1',
#  'drift_475',
#  'mb.a24r3.b1..1',
#  'drift_476',
#  'mb.a24r3.b1',
#  'drift_477',
#  'mb.a24r3.b1..2',
#  'drift_478',
#  'mcs.a24r3.b1',
#  'drift_479',
#  'mb.b24r3.b1..1',
#  'drift_480',
#  'mb.b24r3.b1',
#  'drift_481',
#  'mb.b24r3.b1..2',
#  'drift_482',
#  'mcs.b24r3.b1',
#  'drift_483',
#  'mco.b24r3.b1',
#  'drift_484',
#  'mcd.b24r3.b1',
#  'drift_485',
#  'mb.c24r3.b1..1',
#  'drift_486',
#  'mb.c24r3.b1',
#  'drift_487',
#  'mb.c24r3.b1..2',
#  'drift_488',
#  'mcs.c24r3.b1',
#  'drift_489',
#  'bpm.24r3.b1',
#  'drift_490',
#  'mo.24r3.b1',
#  'drift_491',
#  'mq.24r3.b1..1',
#  'drift_492',
#  'mq.24r3.b1',
#  'drift_493',
#  'mq.24r3.b1..2',
#  'drift_494',
#  'ms.24r3.b1',
#  'drift_495',
#  'mcbv.24r3.b1',
#  'drift_496',
#  'mb.a25r3.b1..1',
#  'drift_497',
#  'mb.a25r3.b1',
#  'drift_498',
#  'mb.a25r3.b1..2',
#  'drift_499',
#  ...)

# %%
collider.lhcb2.elements  # Element objects
# Out:
# (<xtrack.beam_elements.elements.Marker at 0x7f18826298e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882629af0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882629b50>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18826299d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882629c10>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882629df0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882629eb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882629f10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882631040>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882631070>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18826311f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882631340>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18826313a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882631400>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18826314f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18826315b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882631670>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882631730>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18826317f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18826318b0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882631970>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882631760>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882631b20>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882631b80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882631c70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882631d30>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882631df0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882631eb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882631fa0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882631f10>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882632130>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882632280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18826322e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18826128e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882629a30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882629a60>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18826324c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882632430>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882632550>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882632640>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882632700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18826324f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18826328b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882632910>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882632a00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882632ac0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882632b80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882632c40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882632d00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882632dc0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882632e80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882632c70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882635070>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18826350d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18826351c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882635280>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882635340>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882635490>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18826354f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882635550>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882635640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882635700>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18826357c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882635430>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882635970>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18826359d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882635ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882635b80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882635c40>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18826358b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882635df0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882635eb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882635f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882638070>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882638130>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18826381f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18826382b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882638370>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882638430>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882638490>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882638580>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18826386d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882638730>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882638790>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882638880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882638940>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882638a00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882638670>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882638bb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882638c10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882638d00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882638dc0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882638e80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882638f40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263a190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263a100>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188263a1c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263a310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263a370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263a3d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263a490>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263a5e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263a700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263a760>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263a9a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263a970>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188263ac70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263ab80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263ad90>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263adf0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263afa0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882670bb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882608430>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263aaf0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263a580>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263a520>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188263c100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263c250>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263c2b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263c310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263c400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263c4c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263c580>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263c640>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263c700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263c7c0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188263c880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263c670>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263ca30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263ca90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263cb80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263cc40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263cd00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263cdc0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263ce80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263cf40>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188263f190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263f0d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263f1f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263f250>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263f340>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263f400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263f4c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263f130>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263f670>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263f6d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263f7c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263f880>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263f940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263fa00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263fac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263f8b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263fc70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263fcd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263fdc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263fe80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263ff70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263fee0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c1100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c1250>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c12b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c1310>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825c1400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c1070>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c15b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c1610>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c1700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c17c0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825c1880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c14f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c1a30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c1a90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c1b80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c1c40>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825c1d00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c1970>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c1eb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c1f10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c3190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c3100>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825c31c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c3310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c3370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c33d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c34c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c3580>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825c3640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c32b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c37f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c3850>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c3940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c3a00>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825c3ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c3730>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c3c70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c3cd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c3dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c3e80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c3f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c70d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c7130>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c72e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c7370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c7490>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c7550>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c75b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c76d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c76a0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825c7910>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c7a90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c7b50>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c7bb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c7d60>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c7cd0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825c7e50>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c7a00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c9040>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c90a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c9190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c92e0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825c9340>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c9400>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c94c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c9520>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c9610>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c96d0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825c9790>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c9280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c9940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c99a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c9a90>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c9b50>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c9c10>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c9cd0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825c9d90>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c9b80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c9f40>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c9fa0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ca0d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ca190>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ca250>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ca310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ca3d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ca490>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ca550>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ca610>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825ca6d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ca4c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ca880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ca8e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ca9d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825caa90>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825cab50>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ca7c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825cad00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825cad60>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825cae50>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825caac0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18826aa1c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825c73a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188263aca0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263a8b0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825ce100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ce250>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ce2b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ce310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ce400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ce4c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ce580>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ce640>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825ce700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ce4f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ce8b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ce910>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825cea00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ceac0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ceb80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825cec40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ced00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825cedc0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825cee80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825cef40>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825d0190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d00d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d01f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d0250>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d0340>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d0400>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825d04c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d0130>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d0670>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d06d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d07c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d0880>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825d0940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d05b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d0af0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188263a820>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d0ca0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d0be0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d0d00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d0e50>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d0d60>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d0df0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825d2190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d20d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d21f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d2250>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d2340>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d2400>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d24c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d2580>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825d2640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d2430>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d27f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d2850>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d2940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d2a00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d2ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d2b80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d2c40>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d2d00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d2dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d2e80>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825d2f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d40d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d4130>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d4190>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d4280>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d4340>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825d4400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d4070>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d45b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d4610>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d4700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d4370>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d48b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d4910>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882629c40>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d49d0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825d4b20>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d4a60>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d4d30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d4d90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d4e80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d4f40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d7190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d7100>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825d71c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d7310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d7370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d73d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d74c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d7580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d7640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d7700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d77c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d75b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d7970>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d79d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d7ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d7b80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d7c40>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d7d00>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825d7dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d7bb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825d7f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825d7fd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825da100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825da1c0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825da280>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825da3d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825da430>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825da490>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825da580>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825da1f0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825da730>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825da7f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825da8b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825da910>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825daa00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825daac0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825dab80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825da670>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825dad30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dad90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825dae80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825daf40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825dc190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dc100>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825dc1c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dc310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825dc370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dc3d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825dc4c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dc580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825dc640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dc700>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825dc7c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dc880>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825dc940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dcac0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825dca00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dcb80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825dcca0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dcd00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825dcdf0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dceb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825dcfa0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dcf10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825df130>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825df1f0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825df2b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825df0a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825df460>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825df4c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825df5b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825df670>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825df730>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825df3a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825df8e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825df940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dfa30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825df6a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825dfbe0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dfc40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825dfd30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dfdf0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825dfe50>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825dffd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e1070>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e10d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e11c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e1280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e1340>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e1400>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e14c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e1580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e1640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e1700>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825e17c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e15b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e1970>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e19d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e1ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e1b80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e1c40>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e1d00>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825e1dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e1bb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e1f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e1fd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e3100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e31c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e3280>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e3340>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e3400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e34c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e3580>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e3640>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e3700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e37c0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825e3880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e3670>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e3a30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e3a90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e3b80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e3c40>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825e3d00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e3970>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e3eb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e3f10>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e6190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e60d0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825e61f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e62b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e6370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e63d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e64c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e6580>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825e6640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e6130>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e67f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e6850>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e6940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e6a00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e6ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e6b80>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825e6c40>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e6a30>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e6df0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e6e50>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e6f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e6f10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e9100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e91c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e9280>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e9340>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e9400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e94c0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825e9580>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e9760>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e97f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e98b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e99d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e99a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e9c10>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e9be0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e9ee0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e9e50>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825e9fd0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825eb0a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825eb1c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825eb220>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825eb310>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825eb3d0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825eb490>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825eb100>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825eb640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825eb6a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825eb790>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825eb400>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825eb940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825eb9a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825eba90>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ebb50>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825ebc10>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825eb880>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ebdc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ebe20>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ebf40>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ebee0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ed0d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ed190>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ed250>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ed310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ed3d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ed490>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825ed550>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ed340>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ed700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ed760>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ed850>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ed910>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ed9d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825eda90>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825edb50>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ed940>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825edd00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e94f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825e9370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e96a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ede50>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825eddc0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ede80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825edf40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f0190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f0100>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f01c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f0280>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825f0340>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f0130>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f04f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f0550>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f0640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f0700>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825f07c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f0430>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f0970>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f09d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f0ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f0730>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f0c70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f0cd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f0dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f0e80>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825f0f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f20d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f2130>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f2190>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f2280>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f2340>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f2400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f24c0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825f2580>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f2370>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f2730>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f2790>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f2880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f2940>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f2a00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f2ac0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f2b80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f2c40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f2d00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f2dc0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825f2e80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f2c70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f5070>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f50d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f51c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f5340>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f5430>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f5490>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f56d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f56a0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825f58e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f57f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f5a90>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f5af0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f5be0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f5ca0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825f5d60>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f59d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f5f10>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f5f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f7070>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f71f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f7250>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f72b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f73a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18826aa190>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825f5310>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825e9af0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825c7070>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f7460>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f74c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f7580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f7700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f77c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f7880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f7940>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f7a00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f7ac0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825f7b80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f7970>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f7d30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f7d90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f7e80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f7f40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f9190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f9100>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825f91c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f9310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f9370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f93d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f94c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f9580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f9640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f9700>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f97c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f9880>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f9940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f9a00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f9ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f9b80>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825f9c40>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f9a30>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f9df0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f9e50>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825f9f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f9f10>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825fc100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825fc250>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825fc2b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825fc310>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825fc400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825fc070>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825fc5b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825fc610>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825fc700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825fc7c0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825fc880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825fc4f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825fca30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825fca90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825fcb80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825fcc40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825fcd00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825fcdc0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825fce80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825fcc70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ff070>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ff0d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ff1c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ff280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ff340>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ff400>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ff4c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ff580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ff640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ff700>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825ff7c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ff5b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ff970>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ff9d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ffac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ffb80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ffc40>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825ffd00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825ffdc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825fff40>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825ffee0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825820d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882582130>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882582190>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882582280>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882582340>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882582400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882582070>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825825b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882582610>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882582700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882582370>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825828b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882582910>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882582a00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882582ac0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882582b80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825827f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882582d30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882582d90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882582e80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882582f40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882583190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882583100>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825831c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882583280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882583340>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882583400>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825834c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825832b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882583670>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825836d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825837c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882583880>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882583940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882583a00>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882583ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825838b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882583c70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882583cd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882583dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882583e80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882583f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882583ee0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882586100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825861c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882586280>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882586340>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882586400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825864c0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882586580>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882586370>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882586730>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882586790>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882586880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882586940>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882586a00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882586670>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882586bb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882586c10>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882586d00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882586970>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882586eb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882586f10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882589190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882589100>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825891c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882589310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882589370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825893d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825894c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882589580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882589640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882589700>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825897c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825895b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882589970>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825899d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882589ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882589b80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882589c40>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882589d00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882589dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882589e80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882589f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882589ee0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188258c100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258c250>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258c2b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258c310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258c400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258c4c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258c580>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258c640>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258c700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258c7c0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188258c880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258c670>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258ca30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258cb80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258ca90>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258cb20>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188258cd30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258ce80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258cee0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258cf40>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258d040>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258d1c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258d220>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258d280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258d370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258d430>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188258d4f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258d160>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258d6a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258d700>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258d7f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258d8b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258d970>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258da30>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258daf0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258dbb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258dc70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258dd30>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188258ddf0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258dbe0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188258dfa0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882590040>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882590130>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825901f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825902b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882590370>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882590430>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882590220>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882590520>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825905e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882590700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825907c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882590880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882590940>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882590a00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882590ac0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882590b80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882590c40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882590d00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882590dc0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882590e80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882590c70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882593070>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825930d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825931c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882593280>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882593340>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882593490>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825934f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882593550>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882593640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825932b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825937f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882593850>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882593940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882593a00>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882593ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882593730>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882593c70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882593cd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882593dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882593e80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882593f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882593ee0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882595100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882595250>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825952b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882595310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882595400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825954c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882595580>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882595640>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882595700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825957c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882595880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882595940>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882595a00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825957f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882595bb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882595c10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882595d00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882595dc0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882595e80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882595f40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882598190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882598100>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825981c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882598310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882598370>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825983d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825984c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882598580>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882598640>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882598820>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882598970>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825989d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882598af0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882598ac0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882598d30>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882598eb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f1882598f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f1882598fd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259b1c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259b130>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259b2b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259b370>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259b460>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259b310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259b550>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259b610>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188259b6d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259b1f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259b880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259b8e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259b9d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259ba90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259bb50>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259bc10>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188259bcd0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259bac0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259be80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259bee0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259bfd0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259c160>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259c190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259c250>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259c310>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259c3d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259c490>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259c550>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259c610>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259c6d0>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188259c790>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259c580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259c940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259c9a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259ca90>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259cb50>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259cc10>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259c880>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259cdc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188258c970>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825985b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825f5550>,
#  <xtrack.beam_elements.elements.Marker at 0x7f1882598700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259cd00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259cf10>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259cf70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259f100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259f1c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259f280>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259f340>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188259f400>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259f1f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259f5b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259f610>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259f700>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259f7c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259f880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259f940>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259fa00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259fac0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259fb80>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259fc40>,
#  <xtrack.beam_elements.elements.Marker at 0x7f188259fd00>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259faf0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f188259feb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f188259ff10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825a2190>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825a2100>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825a21c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825a2280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825a2340>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825a2400>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825a24c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825a22b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825a2670>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825a26d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825a27c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825a2880>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825a2940>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825a25b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825a2af0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825a2b50>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825a2c40>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825a2d00>,
#  <xtrack.beam_elements.elements.Marker at 0x7f18825a2dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825a2a30>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825a2f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825a2fd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7f18825a4100>,
#  <xtrack.beam_elements.elements.Drift at 0x7f18825a41c0>,
#  ...)

# %% [markdown]
# ### Access the properties of individual elements

# %%
collider.lhcb1['ip1']  # A marker element at one of the collision points (ATLAS experiment)

# %%
collider.lhcb1['mb.b18l3.b1..1']  # A bending magnet

# %%
collider.lhcb1['mb.b18l3.b1..1'].to_dict()  # We can view its properties
# Out:
# {'__class__': 'Multipole',
#  'order': 0,
#  'inv_factorial_order': 1.0,
#  'length': 7.15,
#  'hxl': 0.002549994037004702,
#  'hyl': 0.0,
#  'radiation_flag': 0,
#  'knl': array([0.00254999]),
#  'ksl': array([0.])}

# %%
# A quadrupole
collider.lhcb1['mqwa.a4l3.b1..2']
collider.lhcb1['mqwa.a4l3.b1..2'].to_dict()
# Out:
# {'__class__': 'Multipole',
#  'order': 1,
#  'inv_factorial_order': 1.0,
#  'length': 0.777,
#  'hxl': 0.0,
#  'hyl': 0.0,
#  'radiation_flag': 0,
#  'knl': array([0.        , 0.00096448]),
#  'ksl': array([0., 0.])}

# %% [markdown]
# ### Twiss
#
# Compute orbit, optics and other quantities of interest.

# %%
# Compute the twiss for the first beamline
twb1 = collider.lhcb1.twiss()

# Compute the twiss for the second beamline, and reverse it to have the two in the same reference frame
twb2 = collider.lhcb2.twiss().reverse()

# %%
tw = twb1
fig, (spbet, spco) = plt.subplots(nrows=2, ncols=1, sharex=True)
spbet.plot(tw['s'], tw['betx'])
spbet.plot(tw['s'], tw['bety'])
spbet.set_ylim(bottom=0)
spco.plot(tw['s'], tw['x'], label='x')
spco.plot(tw['s'], tw['y'], label='y')
spco.legend()
spbet.set_ylabel(r'$\beta_{x,y}$ [m]')
spco.set_ylabel(r'(Closed orbit)$_{x,y}$ [m]')

# vertical lines at IPs with labels next to them at the top of the plot
for ip in ['ip1', 'ip2', 'ip5', 'ip8']:
    spbet.axvline(x=tw['s', ip], color='k', alpha=0.2, linestyle='--')
    spco.axvline(x=tw['s', ip], color='k', alpha=0.2, linestyle='--')


fig.suptitle(
    r'$q_x$ = ' f'{tw["qx"]:.5f}' r' $q_y$ = ' f'{tw["qy"]:.5f}' '\n'
    r"$Q'_x$ = " f'{tw["dqx"]:.2f}' r" $Q'_y$ = " f'{tw["dqy"]:.2f}'
    r' $\gamma_{tr}$ = '  f'{1/np.sqrt(tw["momentum_compaction_factor"]):.2f}'
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 0.98, "$q_x$ = 62.31001 $q_y$ = 60.32001\n$Q'_x$ = 2.04 $Q'_y$ = 3.06 $\\gamma_{tr}$ = 53.54")

# %%
plt.figure()

collider.vars['on_x1']=0
collider.vars['on_x2']=100
collider.vars['on_x5']=0
collider.vars['on_x8']=0
tw = collider.lhcb1.twiss()
plt.plot(tw.s, tw.dx)
plt.plot(tw.s, tw.dy)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Measure the tune

# %%
num_turns = 500

p_co = twb1.particle_on_co.copy()

collider.lhcb1.track(p_co, num_turns=num_turns, turn_by_turn_monitor=True)
mon_co = collider.lhcb1.record_last_track

p1 = twb1.particle_on_co.copy()
p1.x += 0.1e-3
p1.y += 0.2e-3
collider.lhcb1.track(p1, num_turns=num_turns, turn_by_turn_monitor=True)
mon1 = collider.lhcb1.record_last_track

tw = twb1

# %%
# Plot turn-by-turn data
fig, (spx, spy) = plt.subplots(nrows=2, ncols=1, sharex=True)
fig.suptitle('Turn-by-turn data')
spx.plot(mon_co.x.T)
spx.plot(mon1.x.T)
spy.plot(mon_co.y.T)
spy.plot(mon1.y.T)
spy.set_xlabel('Turn')
spx.set_ylabel('x [m]')
spy.set_ylabel('y [m]')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0, 0.5, 'y [m]')

# %%
# Plot the transverse spectrum
fig, (spx, spy) = plt.subplots(nrows=2, ncols=1, sharex=True)
fig.suptitle('Transverse spectrum')
freq_axis = np.fft.rfftfreq(n=num_turns)
spx.plot(freq_axis, np.abs(np.fft.rfft(mon1.x[0, :])))
spy.plot(freq_axis, np.abs(np.fft.rfft(mon1.y[0, :])))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Consistent with the twiss

# %%
twb1.qx, twb1.qy
# Out:
# (62.31000536189203, 60.320007176862674)

# %% [markdown]
# ### Survey

# %%
# Run the survey
sv1 = collider.lhcb1.survey(element0='ip1')
sv2 = collider.lhcb2.survey(element0='ip1').reverse()

# %%
# Draw the plot
offset = 200.

twb1_ir1 = twb1.rows[twb1['s', 'ip1']-offset:twb1['s', 'ip1']+offset:'s']
svb1_ir1 = sv1.rows[sv1['s', 'ip1']-offset:sv1['s', 'ip1']+offset:'s']

twb2_ir1 = twb2.rows[twb2['s', 'ip1']-offset:twb2['s', 'ip1']+offset:'s']
svb2_ir1 = sv2.rows[sv2['s', 'ip1']-offset:sv2['s', 'ip1']+offset:'s']

fig, ax = plt.subplots()
fig.suptitle('IP1 (ATLAS experiment)')
ax.plot(svb1_ir1.Z, svb1_ir1.X, label='x', linestyle='--', color='b')
ax.plot(svb2_ir1.Z, svb2_ir1.X, label='y', linestyle='--', color='r')

ax.plot(svb1_ir1.Z, svb1_ir1.X + twb1_ir1.x, label='x', linestyle='-', color='b')
ax.plot(svb2_ir1.Z, svb2_ir1.X + twb2_ir1.x, label='y', linestyle='-', color='r')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# See the whole ring
fig, ax = plt.subplots()
fig.suptitle('LHC Ring')
ax.set_box_aspect(1)
ax.plot(sv1.Z, sv1.X, label='x', linestyle='--', color='b')
ax.plot(sv2.Z, sv2.X, label='y', linestyle='--', color='r')

ax.plot(sv1.Z, sv1.X + twb1.x, label='x', linestyle='-', color='b')
ax.plot(sv2.Z, sv2.X + twb2.x, label='y', linestyle='-', color='r')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.trapz(tw.betx, tw.s)/tw.circumference
# Out:
# 349.71781611563904

# %%
tw.circumference/2/np.pi/tw.qx
# Out:
# 68.09328636624355
